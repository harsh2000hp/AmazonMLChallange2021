# %%
import pandas as pd
import csv

# %%
train = pd.read_csv('dataset/train.csv',escapechar='\\',quoting = csv.QUOTE_NONE)
train.describe()
# Out:
#        BROWSE_NODE_ID
# count    2.903024e+06
# mean     9.211321e+03
# std      5.606280e+04
# min      0.000000e+00
# 25%      7.000000e+02
# 50%      1.072000e+03
# 75%      2.546000e+03
# max      2.893574e+06

# %%
train.head()
# Out:
#                                                TITLE  \
# 0         Pete The Cat Bedtime Blues Doll, 14.5 Inch
# 1  The New Yorker NYHM014 Refrigerator Magnet, 2 ...
# 2  The Ultimate Self-Sufficiency Handbook: A Comp...
# 3   Amway Nutrilite Kids Chewable Iron Tablets (100)
# 4  Teacher Planner Company A4 6 Lesson Academic T...
#
#                                          DESCRIPTION  \
# 0  Pete the Cat is the coolest, most popular cat ...
# 1  The New Yorker Handsome Cello Wrapped Hard Mag...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        BULLET_POINTS           BRAND  \
# 0  [Pete the Cat Bedtime Blues plush doll,Based o...     MerryMakers
# 1  [Cat In A Tea Cup by New Yorker cover artist G...  The New Yorker
# 2                                Skyhorse Publishing          imusti
# ...

# %%
test = pd.read_csv('dataset/test.csv',escapechar='\\',quoting = csv.QUOTE_NONE)
test
# Out:
#         PRODUCT_ID                                              TITLE  \
# 0                1  Command 3M Small Kitchen Hooks, White, Decorat...
# 1                2  O'Neal Jump Hardware JAG Unisex-Adult Glove (B...
# 2                3  NFL Detroit Lions Portable Party Fridge, 15.8 ...
# 3                4  Panasonic Single Line KX-TS880MX Corded Phone ...
# 4                5  Zero Baby Girl's 100% Cotton Innerwear Bloomer...
# ...            ...                                                ...
# 110770      110771  AAHNA E MALL OneBlade Hybrid Trimmer Shaver An...
# 110771      110772  Grin Health N99 Anti Pollution Reusable Washab...
# 110772      110773  Asian Army Pink Ultra reusable respirator clot...
# 110773      110774  IM Safe 3 Ply Non-Woven Disposable Surgical Fa...
# 110774      110775  Artifie 100% Cotton Unisex Reusable Breathable...
#
#                                               DESCRIPTION  \
# 0                                         Sale Unit: PACK
# ...

# %%
train.isna().sum()
# to find null values in all columns in training dataset 
# total 946735 values are missing in dataset
# Out:
# TITLE                 71
# DESCRIPTION       723664
# BULLET_POINTS     166263
# BRAND              56737
# BROWSE_NODE_ID         0
# dtype: int64

# %%
trainAllNullDropped = train.dropna()
trainAllNullDropped
# dropping all null values
# not the optimal approach, but the safest one
# Out:
#                                                      TITLE  \
# 0               Pete The Cat Bedtime Blues Doll, 14.5 Inch
# 1        The New Yorker NYHM014 Refrigerator Magnet, 2 ...
# 5        Men'S Full Sleeve Raglan T-Shirts Denim T-Shir...
# 6                    Glance Women's Wallet (Black) (LW-21)
# 7        Wild Animals Hungry Brain Educational Flash Ca...
# ...                                                    ...
# 2903018  The NXT LVL Liquid Silicone Soft Back Cover Ca...
# 2903019  Premium Aviator Sunglasses - HD Polarized (Bri...
# 2903020  Social Distance Stickers - Set of 5 Sticker Sl...
# 2903021  Torr-to Face Shield PACK OF 5 with Adjustable ...
# 2903022  Type-C to 3.5 MM for Oppo R17 Pro Type-C to 3....
#
#                                                DESCRIPTION  \
# 0        Pete the Cat is the coolest, most popular cat ...
# 1        The New Yorker Handsome Cello Wrapped Hard Mag...
# 5        Men'S Full Sleeve Raglan T-Shirts Denim T-Shir...
# ...

# %%
train
# Out:
#                                                      TITLE  \
# 0               Pete The Cat Bedtime Blues Doll, 14.5 Inch
# 1        The New Yorker NYHM014 Refrigerator Magnet, 2 ...
# 2        The Ultimate Self-Sufficiency Handbook: A Comp...
# 3         Amway Nutrilite Kids Chewable Iron Tablets (100)
# 4        Teacher Planner Company A4 6 Lesson Academic T...
# ...                                                    ...
# 2903019  Premium Aviator Sunglasses - HD Polarized (Bri...
# 2903020  Social Distance Stickers - Set of 5 Sticker Sl...
# 2903021  Torr-to Face Shield PACK OF 5 with Adjustable ...
# 2903022  Type-C to 3.5 MM for Oppo R17 Pro Type-C to 3....
# 2903023                        KNG Orange Polo Tshirt (38)
#
#                                                DESCRIPTION  \
# 0        Pete the Cat is the coolest, most popular cat ...
# 1        The New Yorker Handsome Cello Wrapped Hard Mag...
# 2                                                      NaN
# ...

# %%
train_uniqueBrowse_Node_ID = trainAllNullDropped['BROWSE_NODE_ID'].nunique()
train_uniqueBrowse_Node_ID

# there are 9636 unique integers for browse_node_id
# Out:
# 9636

# %%
sumBrowse_Node_ID = trainAllNullDropped['BROWSE_NODE_ID'].sum()
sumBrowse_Node_ID
sumBrowse_Node_ID/9636

# sumBrowse_Node_ID is the sum of whole last column in non-null training dataset
# Out:
# 2015206.795973433

# %%
sampleSubmission = pd.read_csv('dataset/sample_submission.csv')
sampleSubmission.head(20)
# Out:
#    PRODUCT_ID  BROWSE_NODE_ID
# 0           1               0
# 1           2               1
# 2           3               2
# 3           4               3
# 4           5               4

# %%
test.isna().sum()
# Out:
# PRODUCT_ID           0
# TITLE                7
# DESCRIPTION      10469
# BULLET_POINTS     6786
# BRAND             2430
# dtype: int64

# %%
testAllNullDropped = test.dropna()
testAllNullDropped
# Out:
#         PRODUCT_ID                                              TITLE  \
# 0                1  Command 3M Small Kitchen Hooks, White, Decorat...
# 1                2  O'Neal Jump Hardware JAG Unisex-Adult Glove (B...
# 2                3  NFL Detroit Lions Portable Party Fridge, 15.8 ...
# 3                4  Panasonic Single Line KX-TS880MX Corded Phone ...
# 4                5  Zero Baby Girl's 100% Cotton Innerwear Bloomer...
# ...            ...                                                ...
# 110770      110771  AAHNA E MALL OneBlade Hybrid Trimmer Shaver An...
# 110771      110772  Grin Health N99 Anti Pollution Reusable Washab...
# 110772      110773  Asian Army Pink Ultra reusable respirator clot...
# 110773      110774  IM Safe 3 Ply Non-Woven Disposable Surgical Fa...
# 110774      110775  Artifie 100% Cotton Unisex Reusable Breathable...
#
#                                               DESCRIPTION  \
# 0                                         Sale Unit: PACK
# ...

# %%
test_uniqueBrowse_Node_ID = testAllNullDropped['PRODUCT_ID'].nunique()
test_uniqueBrowse_Node_ID
# Out:
# 97793
